# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
Student_Id = np.random.randint(1256,1300,40)                 #Creating DATABASE

Names = 'Liam Noah William James Logan Benjamin Mason Elijah Oliver  Jacob Emma Olivia Ava Isabella Sophia Tara Mia Charlotte Amelia Evelyn  Murfadh Jack Dowson Titu Hansa Abigail Rahul Sahil Ganesh Hitler Brooke Johnny Sins Krutika Devansh Kattar Hippy Jimmy Timmy Farukh'.split()
Last_names = 'Smith  Johnson  Williams  Jones  Brown  Davis  Miller  Wilson  Moore  Taylor  Anderson  Thomas  Jackson White  Harris  Martin  Thompson  Garcia   Martinez  Robinson  Clark   Rodriguez    Lewis  Lee  Walker Hall Allen  Young  Hernandez King  Wright  Lopez  Hill  Scott   Green   Adams  Baker  Gonzalez  Nelson   Carter'.split()
Department = '  ISE	ISE	ISE	ISE	ISE	ISE	ISE	EM	EM	EM	EM	EM	EM	EE	EE	EE	EE	EE	EE	EE	CMPE	CMPE	CMPE	CMPE	CMPE	CMPE	IT	IT	IT	IT	IT	IT	IT	IT	IT	IT	CIVIL	CIVIL	CIVIL	CIVIL'.split()
Income = np.random.randint(100000,200000,40)
Employement_Status = np.random.randint(0,2,40)
Country = 'Bahamas	Bahrain	Bangladesh	Barbados	Belarus	Belgium	Belize	Benin	Bhutan	Bolivia	Bosnia and Herzegovina	Botswana	Brazil	Brunei	Bulgaria	Burkina Faso	Burundi	Afghanistan	Albania	Algeria	Andorra	Angola	Antigua and Barbuda	Argentina	Armenia	Australia	Austria	Azerbaijan	Gabon	The Gambia	Georgia	Germany	Ghana	Greece	Grenada	Guatemala	Guinea	Guinea-Bissau	Guyana	Haiti'.split()
GPA = np.random.uniform(2.8,4.0,40).round(2)
Fees_Due = np.random.randint(50000,60000,40)


Data_Table = list(zip(Student_Id,Names,Last_names,Department,Income, Employement_Status,Country,GPA, Fees_Due))




df = pd.DataFrame(Data_Table,columns = ['Student_Id','Names','Last_names','Department','Income','Employement_Status','Country','GPA','Fees_Due'])



df.replace(0,'No',inplace =True)
df.replace(1,'Yes',inplace =True)
df['Country'].replace('and','England',inplace =True)

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1259       Liam      Smith        ISE  141122                 No
# 1         1285       Noah    Johnson        ISE  157433                Yes
# 2         1268    William   Williams        ISE  135058                 No
# 3         1275      James      Jones        ISE  142880                Yes
# 4         1277      Logan      Brown        ISE  155854                 No
# 5         1269   Benjamin      Davis        ISE  144320                 No
# 6         1298      Mason     Miller        ISE  127996                 No
# 7         1258     Elijah     Wilson         EM  156931                 No
# 8         1265     Oliver      Moore         EM  155013                Yes
# 9         1264      Jacob     Taylor         EM  122025                Yes
# 10        1283       Emma   Anderson         EM  133738                 No
# ...

# %%
new_id=[i for i in range(123401,123401+len(df))]
df['Student_Id'] = new_id                                #generating employecode where 1234 is fixed and only last digit changing

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0       123401       Liam      Smith        ISE  115707                Yes
# 1       123402       Noah    Johnson        ISE  168598                 No
# 2       123403    William   Williams        ISE  123895                Yes
# 3       123404      James      Jones        ISE  126216                Yes
# 4       123405      Logan      Brown        ISE  172592                 No
# 5       123406   Benjamin      Davis        ISE  175025                 No
# 6       123407      Mason     Miller        ISE  170613                 No
# 7       123408     Elijah     Wilson         EM  149524                 No
# 8       123409     Oliver      Moore         EM  115356                 No
# 9       123410      Jacob     Taylor         EM  190376                 No
# 10      123411       Emma   Anderson         EM  100989                 No
# ...

# %%
df.drop['new']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-f3f45d2c4ac5> in <module>
# ----> 1 df.drop['new']
#
# TypeError: 'method' object is not subscriptable

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1259       Liam      Smith        ISE  119820                Yes
# 1         1258       Noah    Johnson        ISE  103342                Yes
# 2         1292    William   Williams        ISE  140411                Yes
# 3         1277      James      Jones        ISE  108621                 No
# 4         1297      Logan      Brown        ISE  125541                Yes
# 5         1297   Benjamin      Davis        ISE  128409                 No
# 6         1296      Mason     Miller        ISE  144578                 No
# 7         1273     Elijah     Wilson         EM  167275                 No
# 8         1265     Oliver      Moore         EM  192905                 No
# 9         1285      Jacob     Taylor         EM  104230                Yes
# 10        1263       Emma   Anderson         EM  125144                Yes
# ...

# %%
df.drop['new',axis=1]
# Out:
#   File "<ipython-input-8-8e8d910de7a0>", line 1
#     df.drop['new',axis=1]
#                       ^
# SyntaxError: invalid syntax

# %%
    
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1259       Liam      Smith        ISE  141122                 No
# 1         1285       Noah    Johnson        ISE  157433                Yes
# 2         1268    William   Williams        ISE  135058                 No
# 3         1275      James      Jones        ISE  142880                Yes
# 4         1277      Logan      Brown        ISE  155854                 No
# 5         1269   Benjamin      Davis        ISE  144320                 No
# 6         1298      Mason     Miller        ISE  127996                 No
# 7         1258     Elijah     Wilson         EM  156931                 No
# 8         1265     Oliver      Moore         EM  155013                Yes
# 9         1264      Jacob     Taylor         EM  122025                Yes
# 10        1283       Emma   Anderson         EM  133738                 No
# ...

# %%
df.drop('GPA', axis = 1)
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1264       Liam      Smith        ISE  122590                Yes
# 1         1295       Noah    Johnson        ISE  141612                Yes
# 2         1277    William   Williams        ISE  188174                 No
# 3         1274      James      Jones        ISE  185812                Yes
# 4         1275      Logan      Brown        ISE  109941                 No
# 5         1279   Benjamin      Davis        ISE  170890                Yes
# 6         1289      Mason     Miller        ISE  125571                Yes
# 7         1292     Elijah     Wilson         EM  100988                 No
# 8         1278     Oliver      Moore         EM  192312                Yes
# 9         1280      Jacob     Taylor         EM  196791                 No
# 10        1295       Emma   Anderson         EM  180691                 No
# ...

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1264       Liam      Smith        ISE  122590                Yes
# 1         1295       Noah    Johnson        ISE  141612                Yes
# 2         1277    William   Williams        ISE  188174                 No
# 3         1274      James      Jones        ISE  185812                Yes
# 4         1275      Logan      Brown        ISE  109941                 No
# 5         1279   Benjamin      Davis        ISE  170890                Yes
# 6         1289      Mason     Miller        ISE  125571                Yes
# 7         1292     Elijah     Wilson         EM  100988                 No
# 8         1278     Oliver      Moore         EM  192312                Yes
# 9         1280      Jacob     Taylor         EM  196791                 No
# 10        1295       Emma   Anderson         EM  180691                 No
# ...

# %%
Race = 'Black White Asian Hispano '.split()
newRace= Race*10                                   #creating null values, a new coloumn
arr = np.array(newRace)
df['Race']=arr
Category = [np.nan]
cat= Category*40

df['category'] = cat

# %%
sample1 = [21312, 21123,123]*10
sample2= [np.nan]*10
len(sample1)                                             #creating null values, a new coloumn
sam = sample1+sample2
sample =np.array(sam)
df['Sample']=sample

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0       123401       Liam      Smith        ISE  188388                 No
# 1       123402       Noah    Johnson        ISE  143954                Yes
# 2       123403    William   Williams        ISE  154466                 No
# 3       123404      James      Jones        ISE  198972                 No
# 4       123405      Logan      Brown        ISE  140577                 No
# 5       123406   Benjamin      Davis        ISE  174183                 No
# 6       123407      Mason     Miller        ISE  175263                Yes
# 7       123408     Elijah     Wilson         EM  152839                Yes
# 8       123409     Oliver      Moore         EM  122434                Yes
# 9       123410      Jacob     Taylor         EM  167280                Yes
# 10      123411       Emma   Anderson         EM  155367                 No
# ...

# %%
values= {'Sample': 0}                    #replacing null values of specific coloumns
cat2 = {'category':'NULL'}
df.fillna(value=values)
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0       123401       Liam      Smith        ISE  184244                Yes
# 1       123402       Noah    Johnson        ISE  156223                Yes
# 2       123403    William   Williams        ISE  185239                 No
# 3       123404      James      Jones        ISE  125186                 No
# 4       123405      Logan      Brown        ISE  118093                 No
# 5       123406   Benjamin      Davis        ISE  106609                 No
# 6       123407      Mason     Miller        ISE  147108                Yes
# 7       123408     Elijah     Wilson         EM  157417                Yes
# 8       123409     Oliver      Moore         EM  170631                Yes
# 9       123410      Jacob     Taylor         EM  118981                Yes
# 10      123411       Emma   Anderson         EM  172704                 No
# ...

# %%
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1264       Liam      Smith        ISE  122590                Yes
# 1         1295       Noah    Johnson        ISE  141612                Yes
# 2         1277    William   Williams        ISE  188174                 No
# 3         1274      James      Jones        ISE  185812                Yes
# 4         1275      Logan      Brown        ISE  109941                 No
# 5         1279   Benjamin      Davis        ISE  170890                Yes
# 6         1289      Mason     Miller        ISE  125571                Yes
# 7         1292     Elijah     Wilson         EM  100988                 No
# 8         1278     Oliver      Moore         EM  192312                Yes
# 9         1280      Jacob     Taylor         EM  196791                 No
# 10        1295       Emma   Anderson         EM  180691                 No
# ...

# %%
df
# Out:
#     Student_Id      Names Last_names Department  Income Employement_Status  \
# 0         1293       Liam      Smith        ISE  143864                 No
# 1         1273       Noah    Johnson        ISE  126522                 No
# 2         1298    William   Williams        ISE  167756                Yes
# 3         1266      James      Jones        ISE  190367                Yes
# 4         1286      Logan      Brown        ISE  117655                Yes
# 5         1275   Benjamin      Davis        ISE  151383                 No
# 6         1270      Mason     Miller        ISE  182369                Yes
# 7         1263     Elijah     Wilson         EM  142611                Yes
# 8         1266     Oliver      Moore         EM  160240                 No
# 9         1293      Jacob     Taylor         EM  119151                 No
# 10        1286       Emma   Anderson         EM  102146                 No
# ...

# %%
Dept = df.groupby('Department') #groupby method

# %% [markdown]
# df

# %%
df.groupby('Fees_Due').describe().transpose() #using describe and transpose
# Out:
# Fees_Due              50437      50948      51054      51319      51543  \
# GPA        count       1.00       1.00       1.00       1.00       1.00
#            mean        3.41       2.86       3.55       2.82       3.83
#            std          NaN        NaN        NaN        NaN        NaN
#            min         3.41       2.86       3.55       2.82       3.83
#            25%         3.41       2.86       3.55       2.82       3.83
#            50%         3.41       2.86       3.55       2.82       3.83
#            75%         3.41       2.86       3.55       2.82       3.83
#            max         3.41       2.86       3.55       2.82       3.83
# Income     count       1.00       1.00       1.00       1.00       1.00
#            mean   122434.00  175807.00  175263.00  118519.00  135347.00
#            std          NaN        NaN        NaN        NaN        NaN
#            min    122434.00  175807.00  175263.00  118519.00  135347.00
# ...

# %%
#JOINING DATAFRAMES:

# %% [markdown]
# df = pd.DataFrame({A:[0,1,2,3], B:[4,5,6]})

# %%
df1 = pd.DataFrame({'A':[0,1,2,3], 'B':[4,5,6,7], 'C':[8,9,10,11], 'Key':[1,2,3,4]},index =[0,1,2,3])
df2 = pd.DataFrame({'D':[12,13,14,15], 'E':[16,17,18,19],'F':[20,21,22,23], 'Key':[1,2,3,4]},index =[4,5,6,7])
df3 = pd.DataFrame({'G':[127,137,147,157], 'H':[167,177,187,197],'F':[20,21,22,23], 'Key':[1,2,3,4]},index =[8,9,10,11])
df4 = pd.DataFrame({'Rahul':[127,137,147,157], 'Harsh':[167,177,187,197],'Frank':[20,21,22,23], 'Key':[1,2,3,4]},index =[12,13,14,15])

# %%
pd.concat([df1,df2,df3,df4]) #concatenate different lists. It will glue all the list
# Out:
# C:\Rahul\Python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       A    B     C     D     E     F  Frank      G      H  Harsh  Key  Rahul
# 0   0.0  4.0   8.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    1    NaN
# 1   1.0  5.0   9.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    2    NaN
# 2   2.0  6.0  10.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    3    NaN
# 3   3.0  7.0  11.0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    4    NaN
# 4   NaN  NaN   NaN  12.0  16.0  20.0    NaN    NaN    NaN    NaN    1    NaN
# 5   NaN  NaN   NaN  13.0  17.0  21.0    NaN    NaN    NaN    NaN    2    NaN
# ...

# %%
pd.concat([df1,df2,df3,df4],axis = 1 )
# Out:
#       A    B     C  Key     D     E     F  Key      G      H     F  Key  \
# 0   0.0  4.0   8.0  1.0   NaN   NaN   NaN  NaN    NaN    NaN   NaN  NaN
# 1   1.0  5.0   9.0  2.0   NaN   NaN   NaN  NaN    NaN    NaN   NaN  NaN
# 2   2.0  6.0  10.0  3.0   NaN   NaN   NaN  NaN    NaN    NaN   NaN  NaN
# 3   3.0  7.0  11.0  4.0   NaN   NaN   NaN  NaN    NaN    NaN   NaN  NaN
# 4   NaN  NaN   NaN  NaN  12.0  16.0  20.0  1.0    NaN    NaN   NaN  NaN
# 5   NaN  NaN   NaN  NaN  13.0  17.0  21.0  2.0    NaN    NaN   NaN  NaN
# 6   NaN  NaN   NaN  NaN  14.0  18.0  22.0  3.0    NaN    NaN   NaN  NaN
# 7   NaN  NaN   NaN  NaN  15.0  19.0  23.0  4.0    NaN    NaN   NaN  NaN
# 8   NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  127.0  167.0  20.0  1.0
# 9   NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  137.0  177.0  21.0  2.0
# 10  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  147.0  187.0  22.0  3.0
# 11  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN  157.0  197.0  23.0  4.0
# ...

# %%
kar = pd.merge(df1,df2,how='inner',on='Key') #making Key as an index column

# %%
#making a n new dataaset #USING MERGE

# %%
Left  = pd.DataFrame({'Key1':['K0','K0','K1','K2'], 'Key2':['K0','K1','K0','K1'], 'A':['A0','A1','A2','A3'], 
                      'B':['B0','B1','B2','B3'] })

# %%
right = pd.DataFrame({'Key1':['K0','K1','K1','K2'], 'Key2':['K0','K0','K0','K0'],
                     'C': [ 'C0','C1','C2','C3'],
                      'D':['D0','D1','D2','D3']})

# %%
pd.merge(Left,right,how='inner',on=['Key1','Key2'])
# Out:
#   Key1 Key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
#USING JOINING: Joining is a convinient method for combining the columns of two potentially different- indexed DataFrames into a
#singe result DataFrame.

# %%
Left1 = pd.DataFrame({'A':[0,1,2,3,4],'B':[5,6,7,8,9]},index=[0,1,2,3,4])

# %%
Right1 =  pd.DataFrame({'C':[10,11,21,31,41],'D':[51,61,71,81,91]},index=[0,1,2,3,4])

# %%
Left1.join(Right1, how ='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-364d3b2e6b3a> in <module>
# ----> 1 Left1.join(Right1, how ='inner')
#
# NameError: name 'Left1' is not defined

# %%
#OPERATIONS:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'col1':[1,2,3,4], 
                  'col2':[444,555,666,444],
                 'col3':['abc','def','ghi','xyz']})

# %%
df['col2'].unique()    #returns the unique value of an column
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique() #returns number of unique values in an column
# Out:
# 3

# %%
df['col2'].value_counts()              #how many times each unique value occured in that column
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[df['col1']>2]                              #return nos in col2 > 2
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df[(df['col1']>2)& (df['col2']<600)]

#return col1>2 and col 2 <600
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
def times2(x):
    return x**2

# %%
df['col2'].apply(times2)
# Out:
# 0    197136
# 1    308025
# 2    443556
# 3    197136
# Name: col2, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)                                              #using lambda expressions
# Out:
# 0    197136
# 1    308025
# 2    443556
# 3    197136
# Name: col2, dtype: int64

# %%
df.sort_values('col2')                                        #sorting a dataframe
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()                                                          #to find null values in a dataframe
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
                                         #pivot table

# %%
df = pd.DataFrame({'A':['foo','foo','foo','bar','bar','bar'],
                  'B':['one','one','two','two','one','one'],
                  'C':['x','y','x','y','x','y'],
                  'D':[1,3,2,5,4,1]})

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(index = ['A','B'],columns=['C'],values=['D'])
# Out:
#            D
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
#DATA IMPORT AND EXPORT WITH PANDAS:

# %%
#in order to work with html and SQL instal the below libraries:

conda install sqlalchemy
conda install lxml
conda install html5lib
conda install BeautifulSoup4
# Out:
#   File "<ipython-input-110-c4e58576fdb5>", line 3
#     conda install sqlalchemy
#                 ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('brics.csv')

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#   BRICS = initial   country  population
# 0             ind     india        9090
# 1             pak  pakistan     9099000

# %%
df1['Currency'] = ['INR','PNR']

# %%
df1.to_csv('newbrics.csv',index=False)

# %%
pd.read_csv('newbrics.csv')

# %%
    

#MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline #this will allow you to see the plots you create inside jupyter notebook

# %%
import numpy as np

# %%
x = np.linspace(0,10,10)

# %%
y = x**2

# %%
plt.plot(x,y,'r')
plt.xlabel('x-axes')
plt.ylabel('y-axes')      #Functional Method
plt.title('MY CHART')
# Out:
# Text(0.5, 1.0, 'MY CHART')

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r')

plt.subplot(1,3,2)    #Functional Metod
plt.plot(y,x,'b')

# %%
#Object Oriented:

# %%
fig =plt.figure()
axes= fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
figure1 =plt.figure()
axes1= figure1.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y,'r')
axes1.set_title('Larger Plot')
axes1.set_xlabel('x-axis')
axes1.set_ylabel('y-axis')

axes2 = figure1.add_axes([0.7,0.1,0.2,0.2]) #values should be 0 and 1
axes2.plot(y,x,'G')
axes2.set_title('Smaller Plot')
axes2.set_xlabel('x-axis')
axes2.set_ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x = np.array([100,200,300,400,500,600,700,800,900,1000])
y= np.random.randint(0,1000,10)

# %%
plt.plot(x,y)
plt.title('My-Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'G')
plt.xlabel('xaxis')
plt.ylabel('yaxis')



plt.subplot(1,2,2)
plt.plot(y,x,'b')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
# Out:
# Text(0, 0.5, 'yaxis')

# %%
graph = plt.figure()
value = graph.add_axes([0.1,0.1,0.8,0.8])
value.plot(x,y,'B')
value.set_title('larger plot')
value.set_xlabel('x-axes')
value.set_ylabel('y-axes')

value2 = graph.add_axes([0.6,0.1,0.3,0.3])
value2.plot(y,x,'r')
value2.set_title('smaller plot')
value2.set_xlabel('X-axes')
value2.set_ylabel('Y-axes')
# Out:
# Text(0, 0.5, 'Y-axes')

# %%
plt.subplot(1,4,1)
plt.subplot(1,4,2)
plt.subplot(1,4,3)
plt.subplot(1,4,4)

# %%
x=np.linspace(0,10,10)
y=x**2
z=x**3
z1=x**4
fig,axes = plt.subplots(1,2)
axes[0].plot(x,y,label='XY')
axes[0].plot(x,z, label ='CUBE')
axes[0].plot(x,z1,label='4th root')
axes[0].legend()
axes[0].set_title('Graph 1')
axes[0].set_xlabel('x-axis')
axes[0].set_ylabel('y-axis')


axes[1].plot(y,x)
axes[1].set_title('Graph 2')
axes[1].set_xlabel('x-axis')
axes[1].set_ylabel('y-axis')
plt.tight_layout()

# %%
#adjust the graph size using figsize

# %%
fig = plt.figure(figsize=(8,3))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
axes[0].plot(x,y,'r')
axes[1].plot(y,x,'b')
plt.tight_layout()

# %%
fig.savefig('My_graph.jpg') #saves ur graph

# %%
x=np.linspace(0,10,10)
y=x**2
z=x**3
z1=x**4

# %%
fig = plt.figure(figsize=(8,4))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_title('Big')

axes2 = fig.add_axes([0.6,0.1,0.3,0.2])
axes2.plot(y,x,'G')
axes2.set_title('small')

plt.tight_layout()

# %%
fig,axes = plt.subplots(1,3)
axes[0].plot(x,y,label = 'xy')
axes[0].set_title('1')
axes[0].legend()
axes[1].plot(y,x)
axes[2].plot(x,z)

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'R')

plt.subplot(1,2,2)
plt.plot(y,x,'G')

# %%
#Matplotlib Details:

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,color='Red',lw = 1,alpha = 20,ls='--',marker='o', markersize=6,
         markerfacecolor='Yellow', markeredgewidth= 3,markeredgecolor='green')

# %%
#focusing on the given area of the plot

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,color='Red',lw = 3, ls='--')
axes.set_xlim([0,4]) #focuses on area from 0 to 4
axes.set_ylim([0,20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2cc8df79f7ac> in <module>
# ----> 1 fig = plt.figure()
#       2 axes = fig.add_axes([0.1,0.1,0.8,0.8])
#       3 axes.plot(x,y,color='Red',lw = 3, ls='--')
#       4 axes.set_xlim([0,4]) #focuses on area from 0 to 4
#       5 axes.set_ylim([0,20])
#
# NameError: name 'plt' is not defined
